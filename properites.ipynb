# %%
# %matplotlib inline  

import xarray as xr
import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt

import parflow as pf
from parflow.tools.fs import get_absolute_path
from parflow.tools.io import write_pfb, read_pfb
from parflow import Run

# %% [markdown]
# ## test2

# %%
run_dir = 'test2'
file_name = f'test2.out.porosity.pfb'
test_data = read_pfb(os.path.join(run_dir, file_name))
test_data.shape
# Out:
# (14, 205, 322)

# %%
file_name = f'soil_t2.pfb'
test_data2 = read_pfb(os.path.join(run_dir, file_name))
test_data2.shape
# Out:
# (14, 205, 322)

# %%
plt.imshow(test_data2[2])

# %%
test_data[test_data==1.0] = np.nan

# %%
print(np.nanmin(test_data[0,:,:]))
print(np.nanmax(test_data[0,:,:]))
# Out:
# 0.05
# 0.05

# %%
print(np.nanmin(test_data[1,:,:]))
print(np.nanmax(test_data[1,:,:]))
# Out:
# 0.1
# 0.1

# %%
print(np.nanmin(test_data[2,:,:]))
print(np.nanmax(test_data[2,:,:]))
# Out:
# 0.25
# 0.35

# %%
print(np.nanmin(test_data[3,:,:]))
print(np.nanmax(test_data[3,:,:]))
# Out:
# 0.25
# 0.35

# %%
plt.imshow(test_data[2])
plt.colorbar()

# %%
print(np.nanmin(test_data[13,:,:]))
print(np.nanmax(test_data[13,:,:]))
# Out:
# 0.25
# 0.35

# %%
run_dir = 'test2'
file_name = f'test2.out.perm_z.pfb'
test_data = read_pfb(os.path.join(run_dir, file_name))
test_data[test_data==0] = np.nan

# %%
print(np.nanmin(test_data[13,:,:]))
print(np.nanmax(test_data[13,:,:]))
# Out:
# 0.006
# 0.01

# %%
plt.hist(test_data[13,:,:].ravel())
# Out:
# (array([2093.,    0.,    0.,    0.,    0., 8796.,    0.,    0.,    0.,
#         2715.]),
#  array([0.006 , 0.0064, 0.0068, 0.0072, 0.0076, 0.008 , 0.0084, 0.0088,
#         0.0092, 0.0096, 0.01  ]),
#  <BarContainer object of 10 artists>)

# %%
run_dir = 'test4'
file_name = f'test4.out.perm_z.pfb'
test_data = read_pfb(os.path.join(run_dir, file_name))
test_data[test_data==0] = np.nan

# %%
print(np.nanmin(test_data[13,:,:]))
print(np.nanmax(test_data[13,:,:]))
# Out:
# 0.008
# 0.01

# %%
print(np.nanmin(test_data[2,:,:]))
print(np.nanmax(test_data[2,:,:]))
# Out:
# 0.008
# 0.01

# %%
# plt.plot(test_data[13,:,:])

# %%
run_dir = 'test4'
file_name = f'test4.out.porosity.pfb'
test_data = read_pfb(os.path.join(run_dir, file_name))
test_data.shape
# Out:
# (14, 205, 322)

# %%
plt.imshow(test_data[2])
plt.colorbar()

# %%
test_data[test_data==1.0] = np.nan

# %%
print(np.nanmin(test_data[0,:,:]))
print(np.nanmax(test_data[0,:,:]))
# Out:
# 0.05
# 0.05

# %%
print(np.nanmin(test_data[1,:,:]))
print(np.nanmax(test_data[1,:,:]))
# Out:
# 0.1
# 0.1

# %%
print(np.nanmin(test_data[2,:,:]))
print(np.nanmax(test_data[2,:,:]))
# Out:
# 0.33
# 0.35

# %%
print(np.nanmin(test_data[3,:,:]))
print(np.nanmax(test_data[3,:,:]))
# Out:
# 0.33
# 0.35

# %%
print(np.nanmin(test_data[13,:,:]))
print(np.nanmax(test_data[13,:,:]))
# Out:
# 0.33
# 0.35

# %%
for i in range(13):
    print(np.nanmin(test_data[i,:,:]))
    print(np.nanmax(test_data[i,:,:]))
# Out:
# 0.05
# 0.05
# 0.1
# 0.1
# 0.33
# 0.35
# 0.33
# 0.35
# 0.33
# 0.35
# 0.33
# 0.35
# 0.33
# 0.35
# 0.33
# 0.35
# 0.33
# 0.35
# 0.33
# 0.35
# 0.33
# 0.35
# 0.33
# 0.35
# 0.33
# 0.35

# %%
print(np.nanmin(test_data[5,:,:]))
print(np.nanmax(test_data[5,:,:]))
# Out:
# 0.33
# 0.35

# %%
run_dir = 'test5'
file_name = f'test5.out.porosity.pfb'
test_data = read_pfb(os.path.join(run_dir, file_name))
test_data.shape
# Out:
# (14, 205, 322)

# %%
test_data[test_data==1.0] = np.nan

# %%
print(np.nanmin(test_data[5,:,:]))
print(np.nanmax(test_data[5,:,:]))
# Out:
# 0.1
# 0.25

# %%
plt.imshow(test_data[5,:,:])

# %%
print(np.nanmin(test_data[5,:,:]))
print(np.nanmax(test_data[5,:,:]))
